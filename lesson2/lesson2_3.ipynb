# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint

r = requests.get('https://api.github.com/events')
pprint(r.text)
# Out:
# ('[{"id":"51910796818","type":"CreateEvent","actor":{"id":97435680,"login":"lijboys","display_login":"lijboys","gravatar_id":"","url":"https://api.github.com/users/lijboys","avatar_url":"https://avatars.githubusercontent.com/u/97435680?"},"repo":{"id":1017177421,"name":"lijboys/domain","url":"https://api.github.com/repos/lijboys/domain"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2025-07-10T06:30:25Z"},{"id":"51910796793","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":674458621,"name":"yangyfei106/test","url":"https://api.github.com/repos/yangyfei106/test"},"payload":{"repository_id":674458621,"push_id":25406534944,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"b95a5ec2b5
# ...
