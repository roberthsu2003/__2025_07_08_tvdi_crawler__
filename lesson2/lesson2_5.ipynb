# %%
i = 0
i = i + 25
i
# Out:
# 25

# %%
#複合指定運算子
i = 0
i += 25
i
# Out:
# 25

# %%
total = 0
total += 1
total += 2
total += 3
total += 4
total += 5
total += 6
total += 7
total += 8
total += 9
total += 10

print(total)
# Out:
# 55

# %%
total = 0
for i in range(1, 1001):
    total += i
print(total)
# Out:
# 500500
